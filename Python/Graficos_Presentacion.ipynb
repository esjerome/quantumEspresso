# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[5.5288, 5.2582],[5.7230, 5.4429]], columns=["lateral", "central"], index=['ag13','ag12bic'])

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Central', 'Lateral']
ag12bic = [5.7230, 5.5288] #ag12bic
ag13 = [5.4429, 5.2582 ] #ag13

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, ag13, width, label='Ag13')
rects2 = ax.bar(x + width/2, ag12bic, width, label='Ag12Bic')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Magnetización [a0]')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1),)
plt.show()

# %%
df = pd.DataFrame([['Bismuto', 5.7461],
                   ['Primer Vecino', 5.2978],
                   ['Segundo Vecino', 5.2417],
                   ['Lejano', 5.0666]], 
                  columns=["Átomo", "Distancia al Átomo Central [a0]"])
sns.lineplot(
    marker="o",
    data=df,
    x="Átomo", y="Distancia al Átomo Central [a0]"
    )
x2 = [0,3]
y2 = [5.5288,5.5288]
y3 = [5.7230,5.7230]
# plotting the line 2 points 
plt.plot(x2, y3, 'c--',label = "Distancia Lateral cluster Ag12BiC")
plt.plot(x2, y2, 'r--',label = "Distancia Lateral cluster Ag13",)
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1),)
plt.xticks(rotation=30)
plt.show()

# %%
df = pd.DataFrame([[0.396, 10.806,'ag13'],[0.124, 11.239,'ag12bic']], columns=["Magnetización", "Carga",'cluster'])
df
# Out:
#    Magnetización   Carga  cluster
# 0          0.396  10.806     ag13
# 1          0.124  11.239  ag12bic

# %%
df = pd.DataFrame({"Átomo": ["Bismuto", "Primer Vecino","Segundo Vecino", "Central","Lejano"],
                   "Magnetización μ B": [0.262, 0.268, 0.238, 0.092, 0.049], 
                   "Carga": [14.345,10.883,10.824,11.268,10.777]})

ax = df.plot(x="Átomo", y="Carga", legend=False,rot=30)
ax2 = ax.twinx()
df.plot(x="Átomo", y="Magnetización μ B", ax=ax2, legend=False, color="r")
ax.set_xlabel("Átomo")
ax.set_ylabel("Carga [e]")
ax2.set_ylabel("Magnetización [μB]")
plt.show()

# %%
df
# Out:
#          date  column1  column2
# 0  2018-01-01      555       50
# 1  2018-01-02      525       48
# 2  2018-01-03      532       49
# 3  2018-01-04      585       51

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Ag13', 'Ag12Bic']
lateral = [10.806,10.926] 
central = [11.239,13.338]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, lateral, width, label='Átomo Lateral')
rects2 = ax.bar(x + width/2, central, width, label='Átomo Central')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Carga [e]')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

x2 = [-0.5,1.5]
y2 = [11,11]
y3 = [15,15]
# plotting the line 2 points 
plt.plot(x2, y2, 'r-',label = "Plata Aslado",)
plt.plot(x2, y3, 'c-',label = "Bismuto Aislado")
fig.tight_layout()
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1),)
plt.show()

# %%
labels = ['Ag13', 'Ag12Bic']
lateral = [0.396,0.244] 
central = [0.124,0.002]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, lateral, width, label='Átomo Lateral')
rects2 = ax.bar(x + width/2, central, width, label='Átomo Central')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Magnetización [μB]')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

x2 = [-0.5,1.5]
y2 = [1,1]
y3 = [3,3]
# plotting the line 2 points 
#plt.plot(x2, y2, 'r-',label = "Bismuto Aslado",)
#plt.plot(x2, y3, 'c-',label = "Plata Aislado")
fig.tight_layout()
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1),)
plt.show()
